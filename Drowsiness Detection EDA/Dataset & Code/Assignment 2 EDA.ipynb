# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# # About the Dataset
#
# dataset contains detailed monthly reports from different casino gaming licenses, including information on wagers, winnings, promotional deductions, and total gross gaming revenue.
#
# **Variables**:
# - **Licensee**: The name of the license holder.
# - **Fiscal Year**: The fiscal year of the report.
# - **Month Ending**: The month the report ends.
# - **Wagers**: Total amount wagered.
# - **Patron Winnings**: Total winnings paid to patrons.
# - **Cancelled Wagers**: Wagers that were cancelled.
# - **Online Casino Gaming Win/(Loss)**: Net win or loss from online gaming.
# - **Promotional Coupons or Credits Wagered**: Total amount wagered using promotional credits.
# - **Promotional Deduction**: Total amount deducted as promotions.
# - **Total Gross Gaming Revenue**: Total gross revenue from gaming.
# - **Payment**: Total payment to the license holder.
#
# **source**: https://drive.google.com/file/d/1vC0j1GdO5rvJ4HbwwNtF1WwFK5y1MSpz/view?usp=drive_link

# %% [markdown]
# **Objective**
# - The objective is to gain insights into the performance of online casino gaming over different periods and licenses, and to identify trends and patterns that can inform business and regulatory decisions.

# %% [markdown]
# # Loading the Dataset

# %%
import pandas as pd

data = pd.read_csv('Selected_Online_Casino_Gaming_Data.csv')

# %% [markdown]
# # Data Overview

# %%
display(data.head())
display(data.tail())
display(data.info)
display(data.shape)

# Basic Statistics
basic_statistics = data.describe()
basic_statistics
# Out:
#                               Licensee Fiscal Year            Month Ending  \
# 0         Mohegan Tribe On-Reservation     2023/24  05/31/2024 12:00:00 AM
# 1                  MPTN On-Reservation     2023/24  05/31/2024 12:00:00 AM
# 2  MPI Master Wagering License CT, LLC     2023/24  05/31/2024 12:00:00 AM
# 3                 Mohegan Digital, LLC     2023/24  05/31/2024 12:00:00 AM
# 4         Mohegan Tribe On-Reservation     2023/24  04/30/2024 12:00:00 AM
#
#       Wagers  Patron Winnings  Cancelled Wagers  \
# 0    1605437          1567452                 5
# 1    1563906          1512558               127
# 2  752954349        726763463            764875
# 3  617154241        595462209            876998
# 4    2134318          2099254                70
#
#    Online Casino Gaming Win/(Loss)  \
# 0                            37980
# 1                            51221
# 2                         25426010
# 3                         20815035
# 4                            34994
#
# ...

# %% [markdown]
# # Finding and handling the Missing Values

# %%
missing_val = data.isnull().sum()
missing_val
# Out:
# Licensee                                      0
# Fiscal Year                                   0
# Month Ending                                  0
# Wagers                                        0
# Patron Winnings                               0
# Cancelled Wagers                              0
# Online Casino Gaming Win/(Loss)               0
# Promotional Coupons or Credits Wagered (3)    0
# Promotional Deduction (4)                     0
# Total Gross Gaming Revenue                    0
# Payment (5)                                   0
# dtype: int64

# %% [markdown]
# **There are NO Missing Values**

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt

# List of columns to plot
columns_to_plot = [
    'Wagers', 
    'Patron Winnings', 
    'Online Casino Gaming Win/(Loss)', 
    'Total Gross Gaming Revenue'
]

# Plot histograms for the selected columns
plt.figure(figsize=(12, 8))

for i, column in enumerate(columns_to_plot, 1):
    plt.subplot(2, 2, i)
    plt.hist(data[column].dropna(), bins=30, color='blue', alpha=0.7)
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
